# %%
import torch
import torch.nn as nn
from torch.autograd import Variable

import pandas as pd
import random
import string
import numpy as np

import sys, os

import torch.utils.data as data

os.environ["CUDA_VISIBLE_DEVICES"] = '0'


all_characters = string.printable
number_of_characters = len(all_characters)

artists = [
'ABBA',
'Ace Of Base',
'Aerosmith',
'Avril Lavigne',
'Backstreet Boys',
'Bob Marley',
'Bon Jovi',
'Britney Spears',
'Bruno Mars',
'Coldplay',
'Def Leppard',
'Depeche Mode',
'Ed Sheeran',
'Elton John',
'Elvis Presley',
'Eminem',
'Enrique Iglesias',
'Evanescence',
'Fall Out Boy',
'Foo Fighters',
'Green Day',
 'HIM',
 'Imagine Dragons',
 'Incubus',
 'Jimi Hendrix',
 'Justin Bieber',
 'Justin Timberlake',
'Kanye West',
 'Katy Perry',
 'The Killers',
 'Kiss',
 'Lady Gaga',
 'Lana Del Rey',
 'Linkin Park',
 'Madonna',
 'Marilyn Manson',
 'Maroon 5',
 'Metallica',
 'Michael Bolton',
 'Michael Jackson',
 'Miley Cyrus',
 'Nickelback',
 'Nightwish',
 'Nirvana',
 'Oasis',
 'Offspring',
 'One Direction',
 'Ozzy Osbourne',
 'P!nk',
 'Queen',
 'Radiohead',
 'Red Hot Chili Peppers',
 'Rihanna',
 'Robbie Williams',
 'Rolling Stones',
 'Roxette',
 'Scorpions',
 'Snoop Dogg',
 'Sting',
 'The Script',
 'U2',
 'Weezer',
 'Yellowcard',
 'ZZ Top']


def character_to_label(character):
    """Returns a one-hot-encoded tensor given a character.
    
    Uses string.printable as a dictionary.
        
    Parameters
    ----------
    character : str
        A character
        
    Returns
    -------
    one_hot_tensor : Tensor of shape (1, number_of_characters)
        One-hot-encoded tensor
    """
    
    character_label = all_characters.find(character)
        
    return character_label


def string_to_labels(character_string):
    
    return map(lambda character: character_to_label(character), character_string)


def pad_sequence(seq, max_length, pad_label=100):
    
    seq += [pad_label for i in range(max_length - len(seq))]
    
    return seq


class LyricsGenerationDataset(data.Dataset):
    
    def __init__(self, csv_file_path, minimum_song_count=None, artists=None):
        
        
        self.lyrics_dataframe = pd.read_csv(csv_file_path)
        
        if artists:
            
            self.lyrics_dataframe = self.lyrics_dataframe[self.lyrics_dataframe.artist.isin(artists)]
            self.lyrics_dataframe = self.lyrics_dataframe.reset_index()
        
        if minimum_song_count:
        
            # Getting artists that have 70+ songs
            self.lyrics_dataframe = self.lyrics_dataframe.groupby('artist').filter(lambda x: len(x) > minimum_song_count)
            # Reindex .loc after we fetched random songs
            self.lyrics_dataframe = self.lyrics_dataframe.reset_index()
        
        # Get the length of the biggest lyric text
        # We will need that for padding
        self.max_text_len = self.lyrics_dataframe.text.str.len().max()
        
        whole_dataset_len = len(self.lyrics_dataframe)
        
        self.indexes = range(whole_dataset_len)
        
        
        # Let's get unique artists and form a list
        self.artists_list = list(self.lyrics_dataframe.artist.unique())
        
        # We will need the overall number of artists for 
        self.number_of_artists = len(self.artists_list)
    
    
    def __len__(self):
        
        return len(self.indexes)
    
    
    def __getitem__(self, index):
        
        index = self.indexes[index]
        
        sequence_raw_string = self.lyrics_dataframe.loc[index].text
        
        sequence_string_labels = string_to_labels(sequence_raw_string)
        
        sequence_length = len(sequence_string_labels) - 1
        
        # Shifted by one char
        input_string_labels = sequence_string_labels[:-1]
        output_string_labels = sequence_string_labels[1:]
                
        # pad sequence so that all of them have the same lenght
        # Otherwise the batching won't work
        input_string_labels_padded = pad_sequence(input_string_labels, max_length=self.max_text_len)
        
        output_string_labels_padded = pad_sequence(output_string_labels, max_length=self.max_text_len, pad_label=-100)
        
        ## Adding the artist label
        sequence_raw_artist_name_string = self.lyrics_dataframe.loc[index].artist

        sequence_artist_label = self.artists_list.index(sequence_raw_artist_name_string)
        
        return (torch.LongTensor(input_string_labels_padded),
                torch.LongTensor(output_string_labels_padded),
                torch.LongTensor([sequence_artist_label]),
                torch.LongTensor([sequence_length]) )

    
def post_process_sequence_batch(batch_tuple):
    
    input_sequences, output_sequences, artists, lengths = batch_tuple
    
    splitted_input_sequence_batch = input_sequences.split(split_size=1)
    splitted_output_sequence_batch = output_sequences.split(split_size=1)
    splitted_artists_batch = artists.split(split_size=1)
    splitted_lengths_batch = lengths.split(split_size=1)

    training_data_tuples = zip(splitted_input_sequence_batch,
                               splitted_output_sequence_batch,
                               splitted_artists_batch,
                               splitted_lengths_batch)

    training_data_tuples_sorted = sorted(training_data_tuples,
                                         key=lambda p: int(p[3]),
                                         reverse=True)

    splitted_input_sequence_batch, splitted_output_sequence_batch, splitted_artists_batch, splitted_lengths_batch = zip(*training_data_tuples_sorted)

    input_sequence_batch_sorted = torch.cat(splitted_input_sequence_batch)
    output_sequence_batch_sorted = torch.cat(splitted_output_sequence_batch)
    artists_batch_sorted = torch.cat(splitted_artists_batch)
    lengths_batch_sorted = torch.cat(splitted_lengths_batch)
    
    
    # Here we trim overall data matrix using the size of the longest sequence
    input_sequence_batch_sorted = input_sequence_batch_sorted[:, :lengths_batch_sorted[0, 0]]
    output_sequence_batch_sorted = output_sequence_batch_sorted[:, :lengths_batch_sorted[0, 0]]
    
    # We should probably repeat this over the whole input sequence
    artists_batch_sorted = artists_batch_sorted.expand_as(input_sequence_batch_sorted)

    input_sequence_batch_transposed = input_sequence_batch_sorted.transpose(0, 1)
    artists_batch_sorted_transposed = artists_batch_sorted.transpose(0, 1)
    
    # pytorch's api for rnns wants lenghts to be list of ints
    lengths_batch_sorted_list = list(lengths_batch_sorted)
    lengths_batch_sorted_list = map(lambda x: int(x), lengths_batch_sorted_list)
    
    return input_sequence_batch_transposed, output_sequence_batch_sorted, artists_batch_sorted_transposed, lengths_batch_sorted_list


class RNN(nn.Module):
    
    def __init__(self, input_size, hidden_size, num_classes, num_conditions, n_layers=2):
        
        super(RNN, self).__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.num_classes = num_classes
        self.n_layers = n_layers
        self.num_conditions = num_conditions
        
        # Converts labels into one-hot encoding and runs a linear
        # layer on each of the converted one-hot encoded elements
        
        # input_size -- size of the dictionary + 1 (accounts for padding constant)
        self.characters_encoder = nn.Embedding(input_size, hidden_size)
        
        self.conditions_encoder = nn.Embedding(num_conditions, hidden_size)
        
        self.lstm = nn.LSTM(hidden_size * 2, hidden_size, n_layers)
        
        self.logits_fc = nn.Linear(hidden_size, num_classes)
    
    
    def forward(self, input_sequences, input_sequences_conditions, input_sequences_lengths, hidden=None):
        
        batch_size = input_sequences.shape[1]

        characters_encoded = self.characters_encoder(input_sequences)
        conditions_endoded = self.conditions_encoder(input_sequences_conditions)
        
        encodings_combined = torch.cat((characters_encoded, conditions_endoded), dim=2)

        # Here we run rnns only on non-padded regions of the batch
        packed = torch.nn.utils.rnn.pack_padded_sequence(encodings_combined, input_sequences_lengths)
        outputs, hidden = self.lstm(packed, hidden)
        outputs, output_lengths = torch.nn.utils.rnn.pad_packed_sequence(outputs) # unpack (back to padded)
        
        logits = self.logits_fc(outputs)
        
        logits = logits.transpose(0, 1).contiguous()
        
        logits_flatten = logits.view(-1, self.num_classes)
        
        return logits_flatten, hidden


trainset = LyricsGenerationDataset(csv_file_path='songdata.csv', artists=artists)

trainset_loader = torch.utils.data.DataLoader(trainset, batch_size=50,
                                              shuffle=True, num_workers=4, drop_last=True)

# %%
rnn = RNN(input_size=len(all_characters) + 1,
          hidden_size=512,
          num_classes=len(all_characters),
          num_conditions=trainset.number_of_artists)

rnn.cuda()

learning_rate = 0.001
optimizer = torch.optim.Adam(rnn.parameters(), lr=learning_rate)
criterion = torch.nn.CrossEntropyLoss().cuda()

def sample_from_rnn_conditionally(starting_sting="Why", sample_length=300, temperature=1, artist_label=0):
    
    sampled_string = starting_sting
    hidden = None

    first_input = torch.LongTensor( string_to_labels(starting_sting) ).cuda()
    first_input = first_input.unsqueeze(1)

    # Expand the artist label to have the same size as input sequence
    # we duplicate it in every input
    artist_label_input = torch.LongTensor([artist_label]).expand_as(first_input)

    current_sequence_input = Variable(first_input)
    current_artist_input = Variable(artist_label_input.cuda())

    output, hidden = rnn(current_sequence_input, current_artist_input, [len(sampled_string)], hidden=hidden)

    output = output[-1, :].unsqueeze(0)

    for i in xrange(sample_length):

        output_dist = nn.functional.softmax( output.view(-1).div(temperature) ).data

        predicted_label = torch.multinomial(output_dist, 1)

        sampled_string += all_characters[int(predicted_label[0])]
        current_sequence_input = Variable(predicted_label.unsqueeze(1))

        artist_label_input = torch.LongTensor([artist_label]).expand_as(current_sequence_input)
        current_artist_input = Variable(artist_label_input.cuda())

        output, hidden = rnn(current_sequence_input, current_artist_input, [1], hidden=hidden)
    
    return sampled_string

# %%
# %matplotlib notebook

from matplotlib import pyplot as plt

# importing a list that can be binded with a figure and update
# the figure when being appended
from visualization import VizList

# Creating figure, axes and binding to lists 
f, (loss_axis, validation_axis, train_axis) = plt.subplots(3, 1)

loss_axis.plot([], [])
validation_axis.plot([], [])
train_axis.plot([], [])


loss_list = VizList()
validation_list = VizList()
train_list = VizList()

loss_list.bind_to_axis(loss_axis)
validation_list.bind_to_axis(validation_axis)
train_list.bind_to_axis(train_axis)

loss_axis.set_title('Training Loss')
validation_axis.set_title('Validation Set Accuracy')
train_axis.set_title('Training Set Accuracy')


plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
clip = 1.0
epochs_number = 1000

for epoch_number in xrange(epochs_number):

    for batch in trainset_loader:

        post_processed_batch_tuple = post_process_sequence_batch(batch)

        input_sequences_batch, output_sequences_batch, artists_batch, sequences_lengths = post_processed_batch_tuple

        output_sequences_batch_var =  Variable( output_sequences_batch.contiguous().view(-1).cuda() )
        
        
        input_sequences_batch_var = Variable( input_sequences_batch.cuda() )
        artists_batch_var = Variable( artists_batch.cuda() )
        
        optimizer.zero_grad()

        logits, _ = rnn(input_sequences_batch_var, artists_batch_var, sequences_lengths)
        
        loss = criterion(logits, output_sequences_batch_var)
        loss_list.append( loss.data[0] )
        loss.backward()

        #torch.nn.utils.clip_grad_norm(rnn.parameters(), clip)

        optimizer.step()
        
    print(sample_from_rnn_conditionally(artist_label=trainset.artists_list.index("Kanye West")))
    torch.save(rnn.state_dict(), 'conditional_rnn.pth')
# Out:
# /home/daniil/repos/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:32: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# Why
# Girl sure ray sromen braty cooder anbona
# I staC
# Yeantighta hing, f-raped stans to man't stome onsile bacr,
# Leah me lamen
# My lanked tall if stuad it to tom no zeack on the boytle to munshide think of for my comestess it so caah feeferno me
# Even dreakin' havin' lan
# (osiil you wan telcer
# Why shake I mon it wicker me
# Don't never long, oh!, I don't zeomin' thannit more you, Leae, a futous, grun
# I'm min't just still the hand sceet me in...
#  -Bup-as-ge-[Chis, lood fay
# Being line Gons
# We wastedmy something estay kind) without in this of you, hand
# Cause of then down
#
# It's rig
# Why nobody will stand Kyess
# And you Calling if you are the still the parpho fun
#
# In the tilk grists my neyte
# You guick on the could bentyry now
# Put thought Ted Dodry
# Are you get a kill outterne.
# Hand embel up
# Onow in friends thross chitting
# Don't phtent at I'll be might?
# If Benaches
# Whyme, talkin' for you like What's I don't want give me exact
# Undight, Every-No]
#
# Now I keep used out
# I'm a kinging in the only you're
# Give, it'ble got around
# Nothing we'll be Supposed ot's whispers is sweet
# They was beaning my first stop everyone
# Hey, lets and the star to drub,
# We went g
# Why I'm stick beating
# With him he guess divime, tickin' bum forman nice light
# Lives inside with mer's hed the rain
# While you weild out that baby and this is the tendies
# To give me days like everything is those
# Spend me to see the hungry that asleep
# SCa yeah and you know what we,
# Oh she sa
# Why'd nothing go do
# On the ten just tell it
# Tempty rules who though too look
# Get the phone veound of neede
# I sit me Lavioo, all a-alway right?
# (I'm yours and that's) laby) more, oh,
# Of amorai !R. O. S-N-3. N-be-Le-CO.:, DelitE
#
# I'll never say floor
# Look me on to awe ya die home and gone a
# Why I'll show you ready
# This time I just last long, so how how him
#
# When you have to see the Liakate hurgle afted
# If for that shit
# Yeah, my lafe that we wouldn't you try
# That you pray in the photicagic
# Together killed with your turn
# He's shake my way
# And the way the world of icer to t
# Why is all cra but the past
# Take the way
#
# Child new waiting to get goin' morning
# Just being about how I toes
# Now I wondern this sprain
# But when it rollator of rescus
# I going what you show it look
#
# Go! Oh Johnnis]
# Brig Banglergeno
# All psycal cause if I see
# All the real blow
# Tel
# Why thing her eyes to shine to be heres
# Got it to the mirrrror statificle
# That feet up the dream through
# Of this word power, baby scress them ralling
# Oh, know I'm she go where there fie
# Spin who you remind it
# And fly good bread why do me
#
# Leave on dogg
# Don't ya, whoa, doesn't like thi
# Why all, when I need with you (Choking up)
#
# I've been opened and for Lex Hoc"
# I'm just worky day Around, One knowlegras
# But now? Was He TV Dogg Way Si>le Bally K So Boull em HPu on DETA"
# Don't do Yoa, that I let it boah.
# Then you come on, rBlick like Zum Lie Alyer,
# I'm burning,
# Yeah, th
# Why've take a phyself a oceless
# Those thousand thing I gotta kniggy, shit bitten
# Gonna take a world out weke with
# I don't care
# I ain't still the sceptic today
# And I'm home tie Lay and then like through
# (Oh then the sun factybake's, Shew, Ah) ya don't remember how long
# Tell that how can yo
# Why did I she just can hear it (back them albout in my little girl with you"
# I don't want hiding the slambles,
# Make it for ya I'm
#
# Already me eat
# You think that she wanna be the fire
# (Ew Earth
# Cut in your sin is a side
# She's the way angel 'n' glosing her own
# Trigard to the bombs
# Pie
# Why won't you lie love me for me to lose the went
# Poor daddy as he don't yo spoke hot fool.
# In a little longer who Jars! when people with the ghoke rewerd tickinted tree
# But I lay me, I got life
#
#
# This is on my spowly do me kinddomy
# What you killed my back spiders are the daze and made us wit
# Why, what, daddy, I was fade
# AK why, I know why, I want to light
# I wanna stupid it down, too long
#
# And when that he going out of hopinas, c'mon break
# Sometimes going the sound?
# In her fight up on homies when I was like about this sollow sense
# She crime I ever didn't be they vin in the whi
# Why go, why? you been the mouth
# Well I can do whatever we know
# On my grouse pretty fight from the coke
#
# I wish I should need to go down
# So whack one day that I took
# In my morgarampagy for a monster than I feel light?
# Be your frierding them all right to tell you like I wear a game
# Krikes
# Why am I do it I'm all pastifes and call story on? What real notta Three about
#
# Young Christice Decrool.
# With the nigga, it's like Cashimazin', but I'll be handy in all right now
# my Wonder and Verk
# Relax, that's what you gotta have cause me
# Why maybe hey and I don't even turn around
# And I c
# Why oh mommy
# When I think I'm diggin' it bitch hush
# Pleasure, you I'll never, wake in
# This is a wood, one's waiting for for you
# Cause i'm on a fool like ya nigga, I'm coming to
# Would ya let you down from me right down to the fuck
# Ten get here with thut, yeah, you know
# Now all I need, yeah
# Why your mind and that mean for the clock cold?
# You will me again
# That was a little bit
# You fallin' from sittin' in the top (Ohhh, Rethin MA AI(I'm caught in Bady. Get outta you rayaliga)
# And I should only warm to walk away from nothing I am
# You say a train of people and put it down day
# Eve
# Why not i do not done on ?
# Its down with the wrong hand people jail
# Rah just to get a bullet and like fire
# We already maguc girl?
# Can you feel it? Da da di
#
#
# Do ya "Da da da da
#
# It's like or work or scarious bad gentle
# Plit me to Choing my Pan Manx:
# Devil in the phone where we've got
#
# Why did I think them honey?
# Splace is the use I stay [Reposed the Tony go on soak)
# The waiting from the heartiesant trip
#
# It's pretty enougfly let's probably
# Silve power that unswers
# They put stressed the bottom
# Reocord being chills, swallow delight
# And same
# This is what I melts
# Wip
# Why there's a kind chill
# If it never had to lose my heart
# Which call' slimmys see me
# And if I was so found, they remember
# Once who I see, we'll work you freshion (oh tears),
# We wanna break down the mother show, then the loving deam
# But, I know there, no human, I hate too long ya'll Ice, I k
# Why wish I'm loving you away
# You baby let's though can you?
# What huh? What? Say I am about?
# I just can't kick it up
# And take a what never enough
# That you're not about to touched
# We were burned out? What the first stars
# I slow never you gonna
# I
# Move is no cared to ask you along
# " Red
# Why an enough
# Imite gold rapping
# Hood myng unnyonic
# I'm just gonna bring act rolcia
# Pull the other girl to juy they like it with his spot
# Now I'm ready Honey Powers
#
# And I ain't been about that laughed
# The alley and be a parion place to be cake
#
# [Chorus]
# How much I always go ready
# Why when I try
# Man
# You crack hard shit on the stars
# But I guess I'd clibent and I wonder where I as
# You gon' be far to see me
# And then love a galent rate
# And have it another story for really want it
# Hey goodbye, emboth clear, you need his muth and swagga
# She will nobody hates before ya li
# Why don ya wanna pay high at all the fool
# But don't let them back whack what the summa's words ya know the time
# Why I know just hope's so tight about her?
# So I promise why will it be a doubt when I'll never feel wearing you
# I'm breaking you down by my gear eyes
# I'll be your man next to me now
# Why did, that?
# Whatever house you wear what I was like
# (When) that Girl can join is more
# I just wanna look in front of the end of them
# It will me if you called me baby, that's ok
# Kitch messess I run from you now I'm legs in my fingernail
#
# How far I be a reputation lot believer
# Haze mone
# Why Can't wait for right? When I get the flow
# In the make bitch whips they nover nature After teat
# I catch and hang out the bombs till necklace
# [Chorus: x3]
# Can't loa la dollar and '6E.K. V lights
#
# And her slip award the harder words
# I've had succural, they said we cut it when they're in
# Why don't you counting the page?
# It seems I'd rather stand up? I was all you can't find sayin
# And if you pretend need to be in the morning
# And I can't disman in the colden shirt.
# No uh huh, that's a remainsteblic 'smas nigga
# I know back the key to you,
# This is revenge of whoa
# No matter ho
# Why don't you know?
# The way hey
# What am I doin'?
# When I could only do
#
# [Verse 2: Michaella]
# And go wrong I've got to rich my only
# Can't spicitude like and I could ever do
# I thought I'll admit
#
# [Verse 2]
# Yeah I'm gone going light? And I'm livin' in
# If I just Kleet like freezin' (
# Why can't you see?
# We had a coop for lights
# And there's nothin' ever worry obsessed kind
# Another big bob you took you down
# Just let the duck out speed
# We can move a while or to lie (feels busted)
#
# Verse:
# Keep your chance
# You gave your bag you will not
# You came for me
# We getting you
# Why don meet y'all?
# They bother motherfucking luck or was niggers got right?
# Robber I hide hitting dempty, weigh when you know I'm abrainness
# i know a miny names, you should go wrong on a
# I use you broke my brandfact, but don't my name
# I show you when that my bags inside of me, Argin
# AMT
#
# Why gotta give them, you would
# Be a bunch off
# There's just what would be so shot?
#
# Yeah, oh, yeah, I never tell you, somebody
#
# So you don't matter any more windowly
# Why do you ask me why you?
# You know this is my nigga, you'll say you know
# I'll never keep this time
#
# The moment in t
# Why, I guess see you schoole but not scribidulo
# Cause you never looking for, "I know you're my full of Confly God?
# 'Hill sticky little Bibber if there's so nice and "I"fit today"
# I could drown" I guess I'm cooling our mouth
# Comin' in, after answered the door, spoon
# Do a differe in the life in
# Why do I remember where I?
# To let me shout! I let a dream that I'm not so?
# Grab ya got enough of my beyong the game
# When I'm trying 'bout my knees like mind
# I said how hard ya that he ate me
# Or a japle undercover
# She know it
# She ain't nothin' anymore
# She say Hurry girl
# And what she ha
# Why)
# Hey hey hey Do-oh
# Hey LP-KC-TE B-Y-R Ohhh, Why They May
# And you want everything
# To roamer fifte, you
# Where's the beat, beat for the back
# We played each day Du-way-hearted alise
# Work in the axe, on the S-Pa-Door?
#
#
# Amen. Pay Another freshmon stars?
#
# (Hey!"
#
#
#
# Vasterday's Vallin
# Why own you
#
#
# When you walk, what you gon? would you?
# Can we be by that?
#
# [Chorus]
#
# 9.bayer's let to fly (go with there up)
# Kanye I ain't
# You can be the lucky twister
# (Come look up!)
# Nut then fly doin yall
# (Na na na, na, na na na na na)
# Let's get a little bit full of loakin'
# (Ya
# Why
# If you only love you the way ya beautifulwood
# Tell us bad affected
# Under those change up and fly
# Got everything I gotta lister this up in
# Doing you to hear them makin it out of you
# And we hit a ritch in a bomb work babe
# That's all we am
# See you ready around the ross
# And your house
# Why can't we stop the way I feel like you again?
# I don't want to see a bit out but me not a light
# Without gettin' it, sometimes
#
# How could the leaghes is gone?
# Now that it seems lost my dreams
# Keeps up and let the greatest drop out
# I thought I had then clothed you off my life I'm waiting
# Why I be "My Budack?s,
# With me, maybe O.
#
# Yeah, my friends come the street you might be a million can steal just.
# You got me growing my good girl do you
# Want you to go shit in your hands.
# Get down get this thing, no-oh-ooh-ooh-oh-ooh
# Buy!
# And one day what I want to do to money
#
# [Cho
# Why I wait no for this
# I was so cause far as I ever tried it
# Work my hommy n-ggas with the presence
# I could be where one Glade
#
# [All]
# Some re-dee-mormas 204s2ians
# South that the girls we dime and filthments
# And get a line
# Before the sweetest poke of his one
# Caon rap brothers
#
# And my
# Why? Why why? Yes you do now
#
# Why wearing the wheels tomorrow they 10 true?
# Who am I gonna believe in me?
# What I'm knowfing? Hy and you know?
#
# What am I gonna save this?
# (I'm holding you this way?)
# I'm looking at you like a nigga, and then they became yours
# The only thing I fall
#
#
# Why did I crawl at you?
# Or that's that so well right?
# Y'all like the most days go hood
# So get down by better
# Hate no regrets
# Well every dick please I've been tolding
# They said god but it's for you but you know boy driver
# Just keep train kickin' out De!
# It's just you and me, offen a new
# Why is it Jyd, everything?
# When I need to
# When we wear that gunin'
# But see it, Riaria, Mick
# Yeah, they think they touch his grass in the cloud x2
# Oh just stop it
# That's for freedom
# I'll be right now
# I'm stillllerades
# That's my niggas
# I'm tired of tired
# The-equinst niggas have a co
# Why carry the girls
# And to got the limos in his good one
# The grey light night
# We know the ones what would I told one
# We wouldn't call hair got me up in
# Semalin home is he would in my apple
# Stars off some things have working
# Ha, that's right, I rise to be
# Good morning not known that I'm
# Why she pain if
# Kneed by the sky things can't say
# Why don't if you feel like a layly big friend yeah?
# What about you?
# When night, did it away
# They don't mind if all
# Can anybody paint on vampings with you
# God late hole in my heart they need
# Now when the healins that's so amazin'
# Ya she
# Why I don't get what I have wrappers
# I'm like old clocks, mama wanna like this
# And I think that she won't listen to the life
# Take it felasion's sweepharate ya knocked clean
# And still cling, felt like that, shit
#
#
# I know, I know you landed me
# Report police, poullion learnerty putters
# But rea
# Why are you thinkin night you was sure that?
# Why from engimitiness have we always step up?
# Your worse shit, you ain't telling 'em,
# But I'm here to pay, baby, I got your games
#
# See you they can see she told her
# You'll never tell me just about the truth I'll off
# My life was better, they wen
# Why on everybody end? Then The BlUs
# Ah, hello, this if I do to be where the things till I feel
# This is like you won't
# No one make me when you
# Until the down things better
# Coz I walked back you bringin' you're waitin'
# Comin' spoil for bein'
# Class my home is wrong
# There's a million more i
# Why can't Do,
# Can you tell me I'm a cold names
# They really never see the thought in mud?
# Before I become and tell me not?
# 'Cause I thought I'd have a tear for that
# I've landed out for me
# The future go hard
# I made the way I was doing
# Guess I'd never understand
# You say what I've do I'd
# Why do you feel my favorite song?
# When will you come on and you love you?
#
# Bifteen he need it?"
#
# This is Nigga. He gotta keep ya
# With that) Hanging Shake (Oh Oobalbow doggy side!" The Famine
# Haters roll brother Like The By
# All Jeanie D'4 Benzedone To Close
# Tell LA Forday's Dohine
# Ahhh
# Why
# How time?
#
# Your sirens sludes we met out the basics of it?
# My ghethoushone is hypnotizude
# Trippled into almost they get through
#
# Bird piece in the shit
# Alsone words that they talked the Jesus Chewtoves sing is deeper
# Dramis Everyone's balling grown so I don't know ya not enough
# And
# Why do you rest what I be this way
# What you wanna want
# What moved all the things go
# Had bitches gon can't be scared
# And I can't be savin' my habit here
# Damn, high, lights!
#
# And I'm too notice that I'm singing
# Ain't even place girl
# I'm still fighting me when I look in Girl gigariters?
# Why a hundred chick piece
# Izabristed some in bitch I blew it?
# Turn around, but don't be demonder or left this superselp
# Always singing the songs to the primato
# Talk sex the Cam headers them these boys many class
# Janie letting pretty sinna lambs so pimp is up!
# Last weekend and prisonately, f
# Why can I hit the dirty?
# When I've suggently perfections? (To the clouds and space)
# Which can hear the game?
# Who is this?
# Cause you can't put you in a party still vinner
# Do ya know, have the furious scrub our??
# I don't wanna find a free me
# Until I finished from my heart
# I know that no o
# Why you obey? You really live?
# I just want to fly
# I told you I'm not bringing a girl like you
#
# So it's now or not
#
# You see G. O. S.O.O.b. But
# And your stones deep then livin' shit
# So far away from a horrok ass dead
# You don't hide it out there masterboard, so the wrong poor
# The Repty Fuc
# Why'cha' you crawl
#
# [CHoop:]
# No, no, no, no no, no, no, no
# What that he do is
# We're all around from me
#
# [Verse: Madelin]
# So
# I've never been
# Not all they getted from
# When loom to Drink at palm
# How could they call [Va? x 2, for it Blues, that's Rhandra's daydream
# You ain't take
# Why'am
# I thought we had it for life
# I tried to make you feel like I had
# To numberbance in land
# In this life we open a place perfect I know
#
# You got it opported on
# But if you only hate hurts
# But when I see somethin' else bring
# Baby
# When I show 'em all
#
# And the girls talk
# That can s
# Why I know what I'm thinkin?
# Just like then be on my big knees
# Do you think she give me straight so blue
# Y'all know me say a mic in my mind
# What a killing to skin the big tights
# Yeah, haters ever do the attitude
# Well roarreal for me the value under my ways
# Hats forever wrong
#
# [Chorus]
# Why ya mind, you know? You're so ambulary?
# Tell You've too glad I can test first girl to this all
# And where you were applified?
# She in the affection, rememberchall
# For she seen harm LegSa may not what the city
# I'm french kids for heaven his reputation of a Grammie What Zersta
# He say hey Joe
# Why're I am baby, I need you into loving, go?
# When Old Mama, I'm simper, you know Minda I'll use you, I will taste it?
# Yes I did it, I'd never see exchanged, I told you, that's in it
# You can't claim you, Don't let nobody change, oil man you at, hold you, it's like that? (I don't live a girl that
# Why'd ya go away? What about that?
# Cause love is a pretty girl we can go
# Throw 'em sad at home
#
# [Chorus]
#
# 1 3 I should have make
# 'Cause in a voice know much
# yeah or am I amaze for you
# And the girl look on the rail
# Be just like St. L. O.
# I think I met it just we
# It makes it raini
# Why do I think of all the good flow
# Cause after smokiest that's Pero or MiFago (Woo' Fami)
#
#
# They pulled and take picture and hip
# You still spoid mocking fresh de a plagus
# Niggas know Bigger played
# Take looking at you at a fly game should learn to shout
# When I hold him defeat
# Real for fun
# Why I heard sex that in my eyes?
# I've been playin' "They did we gotta break ??? ? ! or American younge Benz of Jay
# And you could use when you hate because it used to believe
# 'Cause nights, your victime your adversions is wrong
# You alone in the ass are dialy
#
# Is what I'm goodbye
# You heard
# Why do you think she's a gay?
# Wishing we'll be apart
# He got more? Why you love to live
# They love you when you walk right
# You feel like that?
# Cause love you lips
# That I like you dream about
# What in the Work is DWangel
# What if this is Christmas
# I?m here with me
# I don't like my style b
# Why does it talk the 5til Pyppy
# I knew it weeks then i wasn't in the bridge
# The ghostlus get in the eyes it's
#
# Bibbers they walk down for the bottle
# Seen my life that's really in me
# That just why I'm Roman
# I'ma make my message
#
# We'd kill you sell me now
# Her mother just give me the top
# Why'd you just dance with me?
#
# Everyday getting hot before you ride
# We need to make it faces
# So if you're away
# Tired of fun but you need to love you
# It's so sure you were thinking of their stbed
# Don't leave you down your head
#
# Hey baby
# Did you ever need a bitch her words?
# Why I wa
# Why would I get?
# Do I have no time?
# Can I still hear you could be heavy?
#
# 'Til honey and I ain't want to lose, 'How many difference wee
# Take the battles on the fountain
# Can bit me sugar of life
# But I could let off but he would've known how I feel like
# Indiager on my heart... oh yeah, ye
# Why you crawler?
# Into the block, I cried started tubbine?
# What was that I ask?
# Impation? only soft labana you then my bad killers?
# Ahh!
# I know you can hear her scene me?
# Yeah he eyes could blow a toast less I couldeviate
# I Wont the table sweaters is something to let 'em know
#
# I take a
# Why was I gotta do?
# I'm looking for the big true
# And I've slow up to a backres off
# I've lost a've been a time
# Somehow I'm gone, you'll be me
# Least I've lived a lift for you
#
# Let me take it til I come back on the news
# My girl gets lookin' at your girlfriends
# My little guitar will blind
# Why'd you go away?
# I hate the way, hey baby
# But how matcha go away
#
# Damn I ask for my colors gang
# Okay, kid till I squeeze my gyas
# And you hate it, but her finn twices
# I got a little legs find some like I'm crazy
# What did you taste this? Shoulda been to fall
#
# [Chorus:]
#
# Lookin'
# Why Why everybody that?
# Why go thru your missing less
# When you talked this way
#
# Soul jyuise
# But you ain't telling you that
# That I just want you to be hard sensish fan
# I, I can't take it away
# I need you right now
#
# [Chorus: x2]
#
# I need to rap 'cause it's like
# I may house and if you
# Why charms, you heard then she leave
# She'll come homies for sadder's broken, doubt a little close
# Hot to hate her, she'd like to say, or love him any other booth
# So I love you, for you to raise me
# Nothing can handle, you never have to wait
# So standing shift, even dice his south
# When I fucki
# Why'am, you did it flickin? (yeah, oh, you don't know?)
# [NIp)
# Down, with everything?
# What up I get, baby I can flat your words?
# Damn when I buys, You flow hoo-hyadells
#
# Got to shine, baby, baby.
# Baby, baby.
# We about
# (hey) Arrange
# (At all)
# This is the sound breathes in here?
# (Now
# Why don't you stand to the Right
# They say Harlcoll
# And tell a voice in a joy without no
# Don't notigatue I'm searching
# Cause I'm fuckin flicker flow
# Alone, OK!
#
# Hard the two of a nigga on the streets weird and smile,
# Infided her earlet pain,
# Which crash, the best played the beat's wron
# Why are you crazy?
# How you ready the way? You was sayin? If you know?
#
# Open your beam unjum harder (ka-mus!)
# We perfect for the night-tribidates
# Haters never make sure that ride right now
# I got shit on the ground but everything we try
# (At the clouds acres was the masses...Ese me"
#
# And
# Why'ach
# They don't know
# Why not when you see
# What more, oh
# Whoa, ha, goon love, love is going to be a glory ?
# Whoa
# Now all I need?
#
# Feels good I'll never fall
# Getting down the sky
# Get up
# I'm gonna try
# Don't take me now
# I'm standing in the window
# I feel a walk
# And I'mma cat
# Why she hated boy she got nigga?
# And the globe and the sadness I'ma to say hello
# Maybe we can cook her clothes
# She few sensation was just an emercent I get
# But she which never bought its heartlassy
# The gas be delarded by hermands holding above they ain't true
# It's sore this message is that
# Why'ach, you got nigga?
# I hated a higher I believe what I got
# (use my momma)
# Now I hate you, so new today
# The glass little thing it lasted
# I guess I just could die for you, brother?
# Why is it this this?
#
# Baby, baby
# I think it's time to go?
# It's like I don't even tell like it ?
# Girl it
# Why do you talk about your nigga?
# Don't ugly inside your skin
# How do you walk
# You been out to stay
# Your mother knew the truth control?
# Girls have always coming back as well sell
# Coming in in the wrong time
# Told you this on the street all
# They name niggas nesses
# Did we doubt through he
# Why can't you feel a way?
# I tell you you'll never have me say her nigga
# With everybody there was just ya
# And say goodbye to herself or scent like TPap
# You thought you Arena, what they say
# (All I need is the promised love affection is three) Afic it's full
# And you're a mom and I can't see yo
# Why'am, I have you flow?
# I'm drifting me with
# Dragmings off and from time
#
# So I'm good to meet my
# Then talk of a loaded gun
# That I leave her, true it is
# I know that I had a lot -
# She say "You have to go?"
# Hypnotized in my Rop B
# So I guess I never got so fast
# But you know they love
# Why can't we fly, all I ever told you bring yo dem a dem a difference
# If everybody else will be our glory is to blame
# They take you to the general of the yaching
# They ain't speakin' from you but they ain't
# I love you, all the worst is over
#
# I gave a damn tooth, the day that I receive it
# I
# Why are you cool if your lone?
# (Wis one time to come to this?
# I'd like to appear when night?
# (I hate this ole with you, with no shot, from the side?)
# Everything in that homie go go
# Girl till my eyes come to stay solvine
# Goodbye my skin years off for all my grind, yeah
# Give you no flashing
# Why would you be awesed for a forming strew
# How many younger played tomorrow consumination?
# Emily duck to the beats forever true
# My mama say on he wear I'm so rolled out since Maryly
# Now I don't need welt you graduation to the likem,
# A song called the of the girls, that they keep it?
# I'm Mi
# Why (Yo, y)
# IGlone, baby
# Unless what you want
# Is what I paint some lonely
# Turn the lights?
# When I think you're out to stay?
# I got nothing left to break my son-for the night
# With thug a glove (can't hurt)
# All these things that I can't handle (all those time)
#
# Oh old Dole corld on!
#
# Why'are you shooting from what I mean?
# I'm huggy crack like, uh, yes I do
# I must hear her hard word that he taught me to
# The one they made it loud
# My brain like a medicy like Texcuses boy
# They'll be on down a ride preach
# She said I gotta love my fast lonely
# You don't like, not put your fa
# Why woo-o-o-on
# Oohhhhhhh
# You girl I'm living up in the whole thing
# I feel you give the city till the days flow
# Spread your hands in the city
# (All New) Kepologi Down that city me
# Because now she got boils, Louis any Day
# Want to break up a gaz, jump to the night ticks
#
# They took court q
# Why words?
# Cause I'm not lookin' for away
# How exit in my heart, and I'll go to hell
# (I'll ever keep you back)
# When I'm finna be that spooned up
# Let's take a ghost instipe and stop the moment seas
# My mouth's true, your gold...in the bells and the question
# I slauge and low livin' liar
# And
# Why would hurt so bad?
# Hi heres go homes
# But I see that hole in their record
# But if they desperate until the sun
# Yeah I know I will
# Girl if you can't try anymore
# Somebody more brand new team for smoke now
# The surprise I'm in
# I love two young now.
# In every shelf or whatever is up
# No
# Why are you ready for me to
# Playing guin?
# When you thought I will get by
#
# B-C-O
# Voices cop Chris
# But I supposed to hit it everywhere the low
# Yellow me back from the night, make you pick it up heateen clothes
# I buy things shine it waits better
# Speak some music slip
# Till it ecstasic i
# Why acting with these art
# And yeah the sun and then
# It's finally obserry
# Why the girl would try be?
# Been right with this bed on all your game
# And my colder's not listenin
# It's perfect as 20 music boss
#
# And i'll be some way out then
# Show you how to make them good
# Come on larger core-
# Why just you call that one?
# How high on his lifetime (me?)
# Just way feel me (still I have to rock rocall)
# There's a higher nigga you know you know
# My fear is calm by
# I'm coming home again
#
# Your my children waired
# But without wearing
# I told you to break it
# I guess it's only in this f
# Why!
#
#
#
#
#
#
#
#
#
#
# Hmmmy by, ah (head hee here)
# Tell me so, so
#
# Booz babe, hold on
# (I got to ball I hate, I hate it)
#
# Talkin', waitin' It n' narraw
# Interror, see the blood insecure will decaya
# Told me I asked, I could make the has over the saddle
# Landa yo knocks, the car, I was young
# You
# Why are you changin' (repon culture?)
# Alright, yeah, or a heartbeat
# For control from the advice and it was you
# You better take your last choice
# On and on rein-dinnamiti (Uh, uh!)
# Can I hit you baby?
# I search out
# That's why I'm coming home
# Yeah the glue skies
# (teasy for me)
# Now I'm t
# Why you tryna learn to fly
# But if you ever felt a big true like the little bitches
#
# And if you ask you worse than you
# And you talk about it, you know me
# How many mimess is anything for you
# And you don't make me, just concertain
# If you want a glob you got your money but you know
#
# Cuz w
# Why she fly to Heil (Some Nike)
# Work amore!
# So anywhere the show
# My scent stiller point master
# And see they use a bigger equilies
# But strippers off, hop is, and bury
# As Jesus saw his fun, quarmine
# But still stay red at 3 (bewarent)
# This is the moment
# This time I'm coming back
# Trial
# Why, you know
# It's not both scorn, crazy
# How could you be so funky
# (Okay that make you hours to disbreek?
# (Too, take my hand?)
# We ain't gonna be a big dough
# (Fuck what the music hit the like boar?)
# (Tell me "so love was right?)
#
# They don't know much (What do it me)
# She said if it's
# Why not to move?
# And where the hidding hat
# They take the sits until it's been better to be inside of you
#
# The second would come as a few
# Till we do work or forgetting
# And don't really worry my friend
#
# And I know this is an angel
# Scared of the wrong time
# Can't afford this thing I can
# Why a shit horse is runnin?
# What about it, Shorty side?
# Or Enginals Royad?
# Do, I'd Do Fare you no more Sadin'
# Well outside that aint a model overth o-votine skalle
# And my mama say ah, Amen, but please
# So uh-uh-huh huh
# You never die with tears
# (Jesus matter on Easter's Diamond chains?)
# Why can I come right here?
# I'm new incredibly, can't come unkind
# You could see what's good to see?
# I believe there's an American genemarells
# And else! He's like, "sailin', "sai!"
#
#
# "This "Sitterboar, has listen"
# "Let me hear ya
# "where's something smother up?
# "I'm supposed to fall in som
# Why as my
# I'm walking too many STory
# Fammburancyz his hitting
# Beneath the dice with the school
# If he tried to kick a leg
# And went to spirit all crushed
# In feet shift, before the lights
# His family worshor, man fags can shake a change
# But he think it's that shitter than the stars
# He was
# Why'aaa
# Hope do hunted down
# And they might wanna hide
# Did we went my weaches and we just
# How many wander is shook for the game
# He gave me everything please, baby
# And I swear it's a razel
# So I'll be lead up again
#
# And I'm trying to get can'f off visits
# Throw the heavens in the abando
# Why would you carry being wrong?
# (Did you think off the way?)
# Cause you know you know
# (How she loves that shit)
# Shine wrong when your leaf away, so
# (slow away)
# (Sweet Louis)
# came the mysteming at, and love it when she like
# (Check who you acts up your girl?)
# She said, I thought it was
# Why are you counting and you know what I'm thinking,
# Thinking, I'm like a blood on the sky with my mind
# Where I had boys like it's me, with me, but there's somebody there it not
# Get lost inside that fuck it, bring your right into spot
# Stop me sweating, we read with S.O.D. Avil' matters
#
# We
# Why am I gonna let them closed
# Uh huh, uh huh, uh guess we just sleep
# They say she was in the line, you are the softless
# Outside, southside, southside
# Was it out when the fuck albums
# Now could ever be slow
# The gin out, we fill-us
# When the dumm, chop 'em on
# Tellin' me miss is espace
# Th
# Why are you breaking your best side?
# How will I be still?
# What did you know you never told me
# Why if I plead, her bad eyes
# And you won't even tell the way nobody please
# My big from the cool bag
# Pardon me now that I'm awareward
# They'll never make you take me all these way too
#
# Nah, nau
# Why are you sick ninety ? (ohh)
# When the sky gets around?
# I see the good clip for us (Sleep)
# Baby you see me with my percentance and
# every day
# Yeah when you pass all the listens on
#
# Feelings with solidates quiet and ask what I hear
# Show my credit with a babyfrical
# Whip when he smell dow
# Why the wind that you want something real
# Started "mmas Gem?"
# You'd be out the colder
# Then mean age what about you, and you ain't even sick
# You can be the real medicine your life jaw
# When divided my hip-hop
# They say that they tauest pushes
# Why you owne? I be hune but we all need
# That yo
# Why can't you contain'
# Where you take your hand
# I know this is
# That shit in the act
# You should know
# That it wouldn't be (but that's alright)
#
# [Verse 2: Kanye Barrefro]
# Yeah, yeah
# Yeah, we gon' feel down
# And you're not like me, yah, oh
# You rubbbrecoc, put it to though
# And if you
# Why
# Why there's something matter
# They never this anybody to?
# What ha
#
# What kind of i poppy kinda pay
# When the court makes everybody they
# We lost all off my legates
# I guess they're next to keep
# Never turn them high
#
# Open your eyes with the sky
# When all the fog's full of very lext
# Why do I went to think?
# What the best side?
# Do you think we'll
# Hey, hey, hey, hey (Lost the show)
# To the grobace at all (and all the glass with the crib)
# Have you look like you and you know?
# (All the floor)
# And then dull be down, all more weed, all of the lowesite
# (How we??)
#
# When f
# Why the floor is for more baby your blowf your fingernest?
# Can't ruin out here, somewhere it's gone
# Star from time, take it in here, building a derge back
# From the grindon million rhymes and rises they slow down the Classic Lew Benz on Controx
# And I'm trying to make it harder to know "Chores, a
# Why around, cocky in the world
# Hoping nigga, yo know you should be pack up
# Lift off, crack meaning, leave
# You lose it with an act attraction
# I'm gonna last night I abse attention
# I'm living in that lights, lights
#
# Back in the window, coal my mind
# I hold the millions and legends
# Will g
# Why would he told her like you and I?
# Can't repent for my Saketon dollar
# Why should I go for cool when you should know?
# After all of my emptiness'er beautif that are a rewind? I told my glory
# A Lift of a whole lot of haters
# Hey Mother's first I forgot
# Shine like Davis Snifffecting for the p
# Why?
# Why I gonna be the good life?
# When I was like (Ohhh)
# When I mean,
# I'm goin' crazy (Some dirty?)
# Come on let me see the game mama
# I'mma be gone
#
# Hey baby am I gon' far? Hitch, nake!
#
# Hate boys talkin' to them, We about all
# Check my baby bye, it alse about how I left my family bad
# Why as the school platinum sight?
# Which way I'm lost? Important
# You lose him when I hit you
# Is it my total suites?
#
# So what you call?
# Cause you had real gone
# Route it all
# I'm comin home
# Yeah I'm on that like that
#
# Look how him again
# Midnible like a shore bitches
# And see the pl
# Why are you shakin? you ready to go?
# How many people go now? That I become hundred and I know
# Why you always be then?
# You've never seen before you chose then
# Girl if you let the crack marching harder the rest of your mind
# Now I'ma try to fly to God cause what about it
#
# And I left me home
# Why would see you mind colous?
# And then we could be he livin' in
# Under them while a foreign
# Lucky just as her time is real, low too
# But me everything he had
# Heard "Orus Heaven heard Up!
#
# Let's have all the few the line but die without having
# Fugs in the church of fallen crack
# Heatfup
# Why we ridin'
# Will fall in love
# Yelloween deep in the diamond rings
# That the sun the good glory
# Isn't an interneaded scared
# Burn that shit in the house
#
# Push me up this true
# It's funny without Chicago is too far
# Would it be on this nigga?
# What are you sayin? Fishaxic
# Work it becam
# Why are you sad and
# Now as you see how you recenter?
# When they spot the food dude of them
# I never thought that you said he procesed that you really matter
# Handed up again we try to pass the ice opene
# God hear this is the blowborn, the other guy I hear everything I
#
# [Spoke:]
# Can anyone h
# Why why doo yeah
# She looked like it's so up mut-frank doverics
# I subjoctorn into vacation, filded of things
# (All that's in love)
# I feel heaven rollers... and I hear the soup I make it
# Shit through Sunday Chi-Towney How Roy Flyer Tay-troupy
# Can I could never see chicken?s and shine
# (Nah, n
# Why amon flare to meet your favories, and that? (Faded my child in my vision)?
# I be my Wale
#
# I pray to God damaged over beating through the farm of a gun
# Y'all know a nigga can't do nothing with taking
# You can ask if they wash away
# The night is dead but wha
# Told me I was so nigga stand be
# Why are you very favorite song?
# I know you see it the same as your gloco-vivac crazy...
#
# You feel it then you can't contain you
# Go into the name of a whole other nigga for your mind
# And you know you love the way that you love your innertimes
#
# You feel like advice emplorsy
# What kind of y
# Why would you talk about it?
# I'm stillin' numba til the end it's done up with
# All the burns against my feet
# With everything I said, we made it to the pose
# That you when they ain't face to break
#
# [Chorus]
# Holidy can't walk wrong
# I'm cold asleep
# When it's late, the dream that I see
# Th
# Why
# Can I have somebody
# Why you know these connection?
# What have I always?
# Yeah
#
# And I'm going over when you love the way I do it that we hang on, go on
# Battle, baby I see you to that you know
#
# Teach me where you going and pleasure my
# your name is now your magic cousines to get a ch
# Why, I, don't forget you (Oh, woa! Hey)
# I know you'll neva persuasy or what they've done
# And you're amore (Don't look down in this life)
# Don't lose you next time
# So pleeser, talk (break me out)
# Baby, baby, did you even worry
# Life of a fool
# Not excited to me and you don't stop it
# If you
# Why are you waiting for the line of a kind of day
# Mami, the homie go up on the moon she made me talk,
# The way that they told me that this is indecisible
# This made I'm talking, the illess of G, 'cause you above
# That the money is silly, the seas lamilying heartalize,
# How much do I hear this?
#
# Why you, you are the weather wet?
# Finishes, cashment he think you're a champion in his needa
# That I can see it's best but
# A far behind a memory, I hate your last shit
# You was this you and me, you know
# I ask you to messy's
# Now hold your dice
#
# I live like inside a dime, some
# I'm not, pa
# Why work?s naked for balling?
# Then say why beyond the way I do evil so ugly healthy
# It's not something that I ain't fair
# If 6 turned on a slurrection
# Count the blood on a Beagm OK
# We broke Eve turned up this busy made goose
# But I know my dick in real leaves
# Baby girl gona do nothing will
# Why am I too young nigga
# Tell me where you become a
# For my G's
# But now what I hear
# I told her that
# You sold the hardest
# Committant you land
# But all you got to say
# Cause I'm always worth
# But one day you lay down her
# I never drink all you down
# Happy you going narry
# My DILL
# For m
# Why just jumped Kanye,
# You ain't gon' get your name into them Slimpton
# For life, you got my girlfriends
# So you in the hometomy shit, I zould Jim
# Yeah I ain't rude, look be good Lennana
# We got to one of them through our kids and hell go
# We depend they swirl out right now, red to get a trip
# Why two infuring
# Feelin' up to the boys of oxygen
#
# (Jesus Walks talkin' 25 defeasey]
#
# In that Twyam pumpin' Above they sayin'
# "Hook:!)
# Too an Euson Comboys up 81
# Tonight this is for the man who you got rough
# Why we on that fly
# To my favorite ass. I'll be the groom
# One thing I foun
# Why and I, I'm
# Yeezy, my Farin's Sn'em side
# It's that poanic wild
# And I check my eye
# All my girls
# Girl, Gotta know Gom because
# Mexican extratedrance, she listen up Edent
# Passion's gon' talked
# So when you put no more
# For me, cause I know she could
# But she Don't Knof Walla
# See her t
# Why you are you? Harlore, HARThy Roulter
# What happened before, please would the bell?
# What do you run, whip or dress me day in the cats
# In the most that was so greedention cars at the flow
# Elevasorapolls and violet repussy
#
# (Hey Mama, we are, put your hands together)
# (Hey Mr.)
# Can I hav
# Why, you should run for it? 'how you off to be good
# When you smokin on, so shining
# They don't know what it means forever to speak down and throw your own refrage
#
# And I, hey, hey, hey
# Do ya do it?
#
# From mely return I'm advice
# Am they way you learn to pay
# Baby, from the people, you nee
# Why are you nothin' f-cking?
# Letting everything go
# Ain't done now, come on get lost a ride
# Oh Won! Let's walk
#
# I walk this way I walked in the wall
# I feel like I saw these I'm paralyed for one thing
# I've seen I found wasn't bought at work
# Flashing light ready for the guy
# Under my Hall
# Why Wid you come you?
# Wine cops just don't be so great
# They'll stop time to get the sun,
# One thing I found
# Yes I will survive than you couldn't find no more
#
# [Bright]
# My pac, sports that I wouldn't speak in Mike SilI
#
# And that's been sent and we
# Twenty-fod is in the club --Ye so sucker
# Why as the few men arross fars
# Still I get my right up outta my dirt throw Awe minutes
# Tidio trapped can't be fallin'
# Don't try to fly in Jesus Wall
#
#
#
# I don't want to have to feel the mask
# There's so much sendin' ya my motherfuckin' dollars
# But they don't mean a little bit joke
# The fly g
# Why amon, you never grown
# Why do you try
# The sky is the soft purple
# They ass foritiest friends home?
#
# (All on your window)
# Life is sweeter than the side of the dreams
# Seas from classy
#
# The snow too far too
# How to put your face to call
# The planet lama, Ardant is a pursun
#
# And guess
# Why around the world from the Hollywood livin
# Hello three, two indurtom, never fellow
# In the end of the call it off the ring
# Southside, southside, everybody getting down
#
# C, motocha list
# Obsey, most that I can
# See I already know who I am
# Mama where around my print you tonight
# One in t
# Why are you saying my name (yeah)
# You fight with me
# I wear your shit so drinking messin decision's breakfast, boy
# So I might never use you, but it wasn't
# And I wonder if you hate me, that'll make me addict
# A different life, babe, that's all I can do is pushed you tigar.
# I go cause I leave y
# Why are you never note?
# I mean it, when you know you really created for us to brain?
# And you made it all in those, you'd ain't heard
#
# Ready for the raz.
# Full batzificallels, you ain't nothing hustling?
# Fuck yeah, uh!
#
# Are you?
#
# You know what the five for me,
# I can make it mine, I
# Why you, who you not?
# I heard the night come to know they
# 'Til then something marged that I got to pop sometime
# Her fave, so always talk to my favorite
# When the pilution's hurtin', but I live
# I lay me down like an act
# Turned around like a hustler
# But boy, that's how good enough do it ?
#
# Why not to, court the Grammy toys, you couldn't come too friends?
# Do you wonder, I can't disagree?
# Why Go Hug? I, so do
# Have you look me?" I said, "Are you sick when I hade of that?
# Raising away, huh!
# L Lullaba baby Dolight diamonds I mix anything, liggas
# When livin' it down, it was just wa
# Why am so my room with no five plans
# The clock, uncontrants to spark in the club
# Who now? Should're extravagan hurried
# Cus and soul, the way I get up everybody
# Still, only want one shoulder than the same
# Why is it flower, I'm in like a difference
#
# And ya don't care for me
# I rubbing over
# Why as the bad say goodbye?
# Tell me what do you think we'll
# Be more of yours and man do it
# I'm livin' on this world
#
# Hold on, holdin' up the club
# So give him sleep, slusses shine
# We going to be callin', get up and fake it
# It's up when you speak with the dreams of egose
#
# And it's tru
# Why who, who, whoa, ?3, 40 yeah hotel was getting real
# do a problem when I told my frenchabe-bye
# Pufffring, rope-brothers
# Hope Seezi, y'all played into these niggas right
# But I'll be calm, scum, oh bitch
#
# Last night, he intervent, freshed to be hustlin
# Funny time, till you get war, Jaw to
# Why ones who need longley girl?
# So0power...
#
# So sweet alternation
# And I'll get you out
# See, scream and slip
#
# Doubleama lonely heart is your last dibe
# Run away fast like I'm coming home again
# My long hair's loud but keep a hearth ain't hardest
#
# If you give your honees, you'll never s
# Why around? The hourg?
#
# Day after day you go far enouge up?
# Into tha lumfished for the falk
#
# We Cell up off that walk(with your hooker)
# Ran away gon' walk out man up with the shore and whiteon
# (bigger we ain't built an word outside road)
#
# [Conguit's Friday Regga
# Gone)
# Money come out a
# Why she fought todo?
# Apride different weed so classic on,
# Then the sun that I used to be
# So now she guess I know that shit, it's on.
# Stand before the way this much
#
#
#
# Shut up x shot, hammere and hammer down.
# My heart is crazy and a hustling like the sword whiskey
# The quarter, but it can't
# Why with music stood they fallin'?
# Aflappin' 'femble ova!
# Hey Nana, Ramie I think they twisted out of me
# Cause they always gon' ask why I'm just a lesson
# We momfor them
# And I'm comin' to Horsus (ohhh........fodily man I'll never been the grammy Flory-
# And the Lingers would off tonight?"
# A
# Why you trip come each of a lift
# No one plays, you know it
# So three
# You following your memory
# They be fine, make a coffield
# Fill me up on this ocean blowing
# I mean green, have you done messy?
#
# And the lights, dogs please
#
# Let this go hooked at your ass go go
# Get down we going so l
# Why are your homey never got ash?
# When you gon' do it?
# Right now, I know you would
#
# (Can't watch that)
# Color down, concertacian,
# I can save it.
# So you under the wall,
# Run, hey, my own bullshit if you want
# And we just love
# Fools and you can ain't ever heroint'
# Since Besencriting:,
# Why are you sad and change for me?
# I see you on my right lights, glory
# Sometimes I feel so amused house,
# And seem to make my daughter asking
# Shine like I used to laugh, Mama's boyfriend of mine
# But then I feel my Burriftheen
# Why did you have to have a difference
# And Day Dine lord, I can h
# Why you're young for me
#
# [J-y-K] You ain't gonna lifted me up niggas
#
# We are at the morning surving
# We ain't capture when it's doubt, that pain
# 'Til then I am almost night
#
# Hey, hey, I need it
# Take me to it, babe
# Yo, it's all over problem, yeah I'm a live and it's a diamond ring
# I
# Why are you and your window, yoa yeah
# Yo, your my life for ya
# I'm so thighs for you is survived
# Why did you come back the resurrection?
# And you might tell me everything
# What can I ask you, baby
#
# Are you than I?m tired of dirty
# A little wet about the eye of E baby trick Right?
# Fed me i
# Why (Oh, yeah)
# From heart into the night
# For you killing days
# My voice vollation to you
# Sweetheart, death in the head
#
# Represent the Christastruct
# Ready to go?
# Rap the credit charge we fall
# Twilks still jumple on my shit
# Rolling to the still can't afford
# Niggas addicted to the Wes
# Why as the freedom?
# I did do it
# And if you reach powdercy on
# ...
# A beautiful a head command all the time
#
# [Verse 1: Hook]
# Anyone
# Man you know I ain't goin go on
# When it don't feel so good
# On the moon when I'm dow
# Why are you so paranoid?
# Can anything on the leval mention and
# Youve got a sadness don't really have we're made
# Anyway, to show you whoa
# We're beautiful like diamonds in the airful, for a thousard of
#
#
# As I plain penut, and then the crowds speed that inspiration
#
#
#
# Throw you on my kids, and
# Why would talk with me, but I keep for you
# Haven't seen 'll right before you ever had to do
# I never knew you keep in love into you
#
# Anyway, I live from all the things that you said
# And oh I wonder if you know
# What you need to hear it
# If I walked ring, you going on the bells
# And we'll ca
# Why are you what you got? Avenue?
# No, no, no, you ain't even brighter than I ever been bringing any old told?
# At least I ain't tryin' to sell your friends just like you!
# I was only five for you, but I never wanted to see,
# But the plan if its a cold one by me,
# I know you see an empty.
#
# [Ch
# Why are you sad and
# God love at all,
# You're cuts for the fakes
# That's the sky
#
# (Kanye)
# (We paw away)
# And did you, amen I touch ya
# She need some time to say
# If a nigga like a longer
# If he did this you can always
# Just to hit her baby
#
# What can I do do
# ?
# (What do we do?)
# Pu
# Why as lots of grammy skinny nigga?
# What said we gon'?? Shaped to toes to have the biggest toothed
# That more girls say I had to talk 'bout who you famous
# And the guillen buy done buy a nigga buy you
# You about a plannets Kanye
# Then the whole plathed up rings
#
# Like Vega get no other skinny
# Why are you so crazy
# Cuz I wish to last forever
# Do Itly held you by you
# Scut the lights, stronger yeah
# When I'm ready to go
# Got a nigga for weak twisted low
#
# Dealing and niggaz they always (On)
# Not for the one (Cigo write)
# Like we a rome of the Chi (I'm hanging)
# I'm from
# Big bits
# Why what you doin' what you are
# For yo y'all (forme to these)
# (forget) From that don't try to feel too
#
#
#
# Let's hear varaulon tonight (ain)
# Jack the roll off that noise, become and
# being in
# Boo-you reel like an American New Chi
# Coming clear and screamin'
# I know Jesass is like la man
#
#
# Why what you didn't you say
# Why you almost was about the same?
#
# Yeah we're hearin' up your side
# Whip to you my baby blush
# Like whites become and be pimps
# And everybody snowin''s way too far
# If ya walk away
#
# Let this on, come on and look home again
# I be married
#
# Okay for the word
# Why are you so paranoid?
# Let's stop paper with your line, you'll be the day to come then,
# Seein' if you take what we need,
# Tell you I know
#
# [Chorus:]
# Happy, baby, go ahead years so.
# Why I'm trynaut' so loud, I ain't packed, (Kanye, you scream so loud?)
# Get off your getchance, yeah,
# Le
# Why would be some Xay five manness?
# Now when the lights dem armous set up from wrong to do.
# And maybe straight rodes ease, in my day have been grey 4 (Beyond the averageravis on a cloud on)
# I know I can do it as well come with me
# (control much cry, I really know what I heard is my nigge"
# Tell
# Why are you a coming
# You high-ever confinitions
# Don't you worry about it
# Baby we gon' do our nigga
# Flow on triagi,
# And fate it week to cot for ancient, it's a profillated
# Yeaaahh without situation after day
# G. Dog B, this is knockin
# We gon' be nictric 'til lonely in the past
# So if you
# Why not doing your big love you up!
# We bringin sweater tighter's left in your eyes
# It isn't you and not know
# What does it feel like to be huncher?
# What if or what you do it?
# And they way true lovers ur a formerance
# Something would like to go?
# Just to hold on, we go, like you know
#
# All
# Why two, what you in, your girlfriend?
# I know you, you know, I knew you would be opporities
# I wonder if you knew how our own
#
# [Chorus:]
#
# Hey, hey, hey, hey, hey
# Don't say no, yeah when you treat these hiding
# You got to pump 'em my, bag and slip the light
#
# You don't see in your veins
# Why are you a child in a throne
# We the Jesus and G, 2x, screws your parache tomoth
# And you were uncafful niggas went checked off flying off
# Hey babe your daddy throat and them now shit up
# And she like the best girl that your hair is on your own quick
# The caress we get down the greatest glorya
# Why are you chose in for these motherfucker
# You shine the lights
#
# Who need a bitch
# How many times cold like you drop her
# You throwthed made like a mexical
# And week from the back of y'all weavins
#
# Haters didn't stop
# Grab your stage
# Baby camera close, I'm in the bar
# Man you well in
# Why are you see you here?
# That you say you was a long haunted friend you the news
# I hear vatash that shit above you before you get
# The same time to get rear ant eagergrafly
#
# Who is it different
# You give it for the limit with
# You run, when you expirging right
# You finish so we can fly at
# Why are you young an inculu boy?
# Can we get your magazines
# That?s what a fuck do go?
#
# They say she dressed up like Jay said
# Talkin' 'bout the no-convicast
# In the right words and bail and I called
# C'mon let's taste the johin off
# Who curry and be packing if y'all world is my drills
# I'm
# Why are you your taroon way
# Chocos that's full of the dream will come to scortablute
# This must be heartless, I'm just gonna be strong
#
# That's the nightmare beat the church that
# She never knows what it about about me
# I know she gone cool and well you about to believe it
# He gettin hard an a
# Why aint fair on the clearerrrrrect in life
# And you would have a cutest time ahead
#
# Who thinks can't fly to give me fly
# All of my mommy fucking with a few dealeters run
# I can't run award the wall
# She wanna give a little lie 'n' attic
# Her momma was I ever think about you
#
# And I can't k
# Why are you she holdin' me
# If one truth or just the one
# Shit is yet all
# I asked him and whisper
# That you real lands
# Her love that leaf
# To get just going to herself in that race
# But if you get haters the only thing that you got,
# Let us live like it's still first
# And if not ride isn't d
# Why would swing like an Americah Aughe, Americah,
# If you out the one as fat as fast certain sorrow chasing and now I'm in
# Still, full of code, I can't write the cure, lah
# You do the matches ways and I summertin Aud, poor you up, the golden get
# Baby, you don't see, gotta have a fuck armbrain
# I
# Why are you sittin' on your own
# What the fun
# One thing in the world
# Cause being a lil fire
# And y'all, and love aim'
#
# Excuse
# Stay years nine
# In every shit
# J. Black adask
# You can say
#
# [Jay-take the Marcis And Mad sway Nem-all)
# When d'y and fly
# My reloades
#
# When I'm dream l
# Why what you did what you say aman shit through your eyes?
# Don't worry? or a nervous written and your goes on me
# Don't talk 'bout this so i'll be homely Nosoma that's made so much
# You're gonna have a Not-ampachy clown way
# come oral-a
# Jump to that B, they ought to decides what chillem told you t
# Why would still be strong?
# Somethin that you just tryin' to slow
# Only greends and we getting over bounds
#
# Cause it's easy go go go-go go go the babbery
# You got other guy creater to the Wrescondoness
# I want it like the world I can do it again
# And be out of burn out then the grind is closin
# Why are you so proud of man
# Games Do our April, Benevished
# Divinna like a flock
# Just because
# As it sucks gon be on
# A coup-remedimes rising
# 'Cause life here went were old
# Been stoppin' by the Emends
# Life is switch and say
# Like white flash-out
# Cus [It's Dort and second Gia)
# Fuck ya
# Why as love was used to love you?
# Wishes forgotten lighted by my lips just to hear you breathe in your life, yeah if I loved you for you no more
# Singing so though? I wouldn't live you everything nigga
# I'd do it for a webritch, you treat me hypn
#
# And my friend and may be good
# My reason for m
# Why not do you put it down yeard?
# ?Dreck it?
# I'm not like the fast stority
# They don't see everything
#
# And you see me in your eyes
# And sleep the door, pop and leters
# And I'm caught up in the conscious
# And I'm gone, I'm so green just a lighter
# I'd like to suffer, why should I creep in it
# Why as love could I?
# I might be more than left me
# Then I spill hang a flag
# I may boy, and stop timely night, now
# 'Cause, so step, suddergene
# Showed me how
# How much that you driven me instead
#
# All of the pain alive
# When I walked into the end
#
# Is it like a young night, drinks?
# Alleen
# Why what you do?
# Don't look night in your eyes
# Why you know you can save you?
# Hey, you don't mean anything that I said if
# When you gon' lie tomorrow to spit you out
# Never thrown this moment you throw a roma told you first
#
# Your my late memory girl
# I'm hanging on to somebody
# I'm tryin
# Why are you stallin' with the party
# You eye like your day-opess
# You want to say
# And we are on your pants
#
# We could have a hush, far from your child
# You can save us a big shot full
# You should have anusoly, you feel 'round
# Can you hear the night, and we?
# Cause we're livin' in
#
# Never
# Why as far what you said
# For me if I could make it all out your streets?
# Cause there's something deaths
# Indown that your everything is
# Still I won't listen
#
#
#
#
# Father, base, baby"
# Hey girl, man
#
# (Beyup girl),
# Tell me when we cut down, mmm. (4 tweeth) Not ya, (Hey Rodmine)
#
# Now this
# Why are you a chumpathet? (Should be part)
# And I'd rather do it again? (Ohhhoooooh)
# I said, for a suck as clock, then
# I need you, back to me
# For anybody told me that you are no more words could never do, (I want you)
# Oh would I ask my damn magic morning
# Baby, I don't like it,
# Cousin pot p
# Why two, whill thing, or a Lade-Caw
# Bitch I'm extrancent, god benda my
# Ice with piece of life, we ain't even mistake
#
# [Chorus]
# Makes everybody seen land
# Mamma want a question!
# Hell night, I just want to see him it layin'
# They poppin' them nigga, this is rattle heat cele
# Those camery a
# Why would she make calls out?
# And when she marrints?
# Trial?
#
# See the host full of glitterssience
# Miamiti till the lights
# Farewest family fact is made
# Miami, I might be on the lowers and the boots over
# I walked in the witches, and the stars
# Still I did it, yeah
#
# And I might stop bu
# Why are you sadder to me
# Tell me what it means
# I'm emotionalmant always staying on my way
#
# That's that shit
#
# Cause I ain't going away
# My my my boyfriend
# Now where I was the only thicker
# And my head still I'm embaring
# You're my cousin or Chi
# When I spit it on the hustler
# Six turt
# Why are you youve, oh, nigga?
# They wanted you falling for you, maybe you call it for the serick you a nigga, that'll be a mid after day
# Don't want to get you out the clothes on, (come on)
# I see the sky but the smell days around me,
# Raps that exthrough, emberrasslet, classic Is
#
# Can I come i
# Why not do...shine who do
# Cause I'll just take plastic in the land you won't des:
# But my baby was a dream
# Shit shorty More ballin', such a blonde hairdress
# Yo kid smoke twitches out the vaseless want nowhere
# [Look at the one that I adore, no, Don't need you now there's that shit
# So what do
# Why whacki in different fast??
# I hear you calling a name doll down the-es
#
# I'm lost in the walls, hype tight
# That's for spoke up and park, color to death,
# Okay
# And, my, facts flow
# Red tunted is an inside me into the kin of the hate into these niggas that I met
# I hear snorts, unpresconiv
# Why would she make everybody when you collake?
# And if she ever did we should be all before you die
# Days we fine? you could look to the leaf bit on their can't fame
# The days they need some things she like she
# Not even if anything's like that
# Because if the sky might last fame when you got she
# Why not we used to have hadpw?
# Maybe we'll try and you know I'm too just said "I don't mean?
# I got a Kam is... Now this me
# I always hadn't make it all behind me and all...
# But saddle cold gin to the door, I could make my guns
# But I'm hearing hoes and a back bearing him
# Been through about ha
# Why are you a couple I'll never
# Want to power this time
# We're bitches in your mine
# Cuz when I'm hopical strewept
# (for you)
# Not to use it
#
# Become teenage with open
# Yeah
#
# Haters do the a long way home
#
# Too high we're as heaven and cold
# Ain't right, do nothing with you wit
# Ever
# Why are you young ant time to play
# They just keep a coupy make a sky
# They say you know, you never feel my skin
# They always say (juice as me?)
# And they ass use it done badge, all these nights getting old
# I know you never, make this game clearing
# Don't make me some good from better now
# [cag
# Why as love was on deny
# To get freaks, we hoppin'
# Haven't doublisuition?
# 'Til homies it works like makin'
# Since Chelcut it outta head
# Came for what you said
# See I don't mind, I deceive
#
# [Jayme New York]
# Just keep on life this time
# Click can get you out to you
# All dem are you actio
# Why are you young another class
# Your magical Pan or a million impossible
# While y'all go grey?
# Take the hat screwed up
# You finally hard to do everything
#
# You're so son, and into reality
# You know what, that you know what's
# Believe me 'cause your verse and the kid
# There's something that
# Why are you supposed to be the same thing?
# When I was like a lift and I fell for me inside?
# What kind-ow demer way do this?
# When you see me for true, the wrong things
# Your introve me lick it like the walls
# They say don't say a word it's awakes
# Stop the fam in my hands
# That's my trustachij
# Why are you so fuckin' 'round?
# And you know did you know what's
# Got a riska of your advantage
# Play by serenatir, everyone we ain't happen to you
#
# [Kanye Welcher keeps freedom!"
# Are you ok the East?
# And I and a nic-tic ya
# Who have' you ready to go?
# Hold up and that's full of dukatora o
# Why would she hate her famous?
# And when she leaves together for months
# She spray bending piss of quites
# And the tubs and the threads will survive
#
# Since we're hitton somethin' denual down
# So tonight to do nothin' swear
# But still only once has ever workers just remains
#
# There's no goin
# Why you awkin dead
# When you keep on your right out of real day
# You'll never tell yourself anymore
# Girl now your diack you dig his primates
# That's how lifted us brighter than years
#
# So why try not to have a hopies
# Paybodol
# How we die in the way to store your plan
# Made us fire and
# How
# Why are you young at quick?
# And you never tell your thought and escape
# You end up screaming, "Wish you? "Never, run after dud""
# You jumpin' don't realiz, that, don't have the yard
# Every jave, you're can't fight it,
# You should take everybody that you don't know it?
# It's so many protostitions
# Why are you young and you action
# And though you're from
# Just to die without connection
# You used to take it till you know its too late
# And I wonder if you know
# What it means (ohh)
# Seem to bein' lemment
# All dem am
# I'm in love with the floor up in the wall
# And it's better than I can't he
# Why are you a couple in your advice like an elemalent
# What the fuck realizage mili, cold night
# Inner and surprise between the affecting
# Still I feel like we're all only One
#
# Are you yeah, oh so we can get on this alone
# If we don't see what it talks, where I could put them?
# I can't let the
# Why would stick like a sea?
# Who might think it's about me that shit? Won't
# Why am I gonna lead you on my feeling
#
# One shit that's so greedy
#
# Euph of many things so then we're asking ours to get a candle break
# The hatin' life was a world that I know did what I did
# All the little whalling of
